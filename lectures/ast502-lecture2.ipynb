# %% [markdown]
# # AST 502, Lecture 2: Tools
#
# Xiaohui Fan (Spring 2020)
#
# Ref: notebooks by G. Richards (2018)

# %% [markdown]
# # Git and Github
#
# We will use a version control system tooll called `git`, and an internet service called [GitHub](http://github.com), that will let you download the notebooks that the lecturers have  put into the class repository before each class. So you need to update our class directory before every class.
#
# # Git
#
# To get Git for any platform, see: [https://git-scm.com/download/](https://git-scm.com/download/).
#
# If you're using a Mac, you'll have `git` installed already. Open a terminal window and run
#
#     $ which git
#
# For example:
#
# ```
# $ which git
# /usr/bin/git
#
# $ git --version
# git version 2.21.1 (Apple Git-122.3)
# ```

# %% [markdown]
# # Let's now dowload the class repository
#
# Once Git is installed, make a place where you are going to put the class repository.  Perhaps in a git subdirectory if you think that you might use more repositories later (we might even for this class!).
# ```
# $ cd ~
# $ mkdir ast502
# $ cd ast502
# ```
#
# Now we need to "clone" the class repository into your account
#
# ```
# $ git clone https://github.com/UA-ast502-2020/classnotebook
# ```
#
# This will make a subdirectory called "classnotebook" and a subdirectory "lectures" in which you will see a file called "ast502-lecture2.ipynb", which is the file that you are reading now.
#
# Before each class, you will want to update this repository so that you get any new files that we have put there for you. Do that with
#
# ```
# $ cd ~/ast502/classnotebook
# $ git pull
# ```

# %% [markdown]
# # Add your lecture to the depository
#
# We should do that the night before your lecture (so that people can update it), and revise it based on how the lecture went (you might not be able to finish it) and the feedback that you have received.
#
#     $ git add ast502-lecture#.ipynb
#
# then commit:
#
#     $ git commit -m "some comments"
#
# finally "push" the changes:
#
#     $ git push
#
# Then make sure github is now updated.

# %% [markdown]
# # Software requirements
#
#
#
#     Anaconda Python 3.6.X  (but 2.7.x should work
#
#     NumPy version 1.14+: efficient array operations
#     SciPy version 1.1+: scientific computing tools
#     matplotlib version 2.2+: plotting and visualization
#     jupyter version 4.4+: interactive computing (formerly IPython)
#     Scikit-learn version 0.19+: machine learning
#     astroML version 0.4+: an astronomical machine learning toolkit

# %% [markdown]
# # Installing astroML
#
# [astroML](http://www.astroml.org/) is the software library that goes together with [the textbook](http://press.princeton.edu/titles/10159.html).  Much of it is a series of wrappers to [scikit-learn](http://scikit-learn.org/), where Jake VanderPlas is one of the main contributors to each.  Jake has written an [Intro to AstroML](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=6382200) paper that is worth going through to give you an idea of the sorts of things that we'll be doing in the class.
#
# AstroML requires `scikit-learn`. Let's install that first using **conda**:
#
# ```bash
# $ conda install scikit-learn
# ```
#
# The astroML packages and add-ons can be installed using **pip** (the python package installer):
#
# ```bash
# $ pip install git+https://github.com/astroML/astroML
# ```
#
# followed by
#
# ```bash
# $ pip install git+https://github.com/astroML/astroML_addons
#
# ```
#
#
# # Installing other things
#
# We'll need a few other packages installed as we go along. Here are the ones that I remembered to write down. You can either install them now, or you can do it later (when you get an error message!).
#
# ```bash
# $ conda install -c astropy astroquery
# ```
#
# ```bash
# $ pip install corner
# ```

# %% [markdown]
# # Jupyter notebooks
#
# In this class, we will use Python almost exclusively through Jupyter Notebooks. To start the notebook app, run:
#
#     $ jupyter notebook
#
# This will pop up a web page in your default browser and show the Dashboard where you can navigate to a particular notebook or open a new one.  You can also open a notebook directly with
#
#     $ jupyter notebook ast502-lecture2.ipynb
#
# If you are creating a new notebook, click on 'new' at the top-right of the page and select 'python'.

# %% [markdown]
# # Working with jupyter notebooks and IPython
#
# Notebooks have two primary cell types: 'Markdown' and 'Code'.    The Markdown cells are basically just for you to read.  The Code cells are meant to be executed (perhaps after you have filled in some blanks).
#
# To execute a cell in the notebook, type '**shift-return**'. If you see a * in the square bracket to the left of the cell or a 'Busy' in the tab title, it means the command is in the process of running, and you need to wait for it to finish.
#
# The notebook is autosaved, so that when you return to a notebook, everything is the same as you left it. If you want to reset it, you can do “revert to checkpoint”.  If you save it yourself, you will create a checkpoint, and the original version will be unavailable.
#
#
#
# Here are some useful IPython commands to get you started (# followed by text indicates a comment and not what you type)!
#
#     In [ ]: ?          # basic help function.  Pops open a sub-frame at the bottom of page.
#                          Close with "x".
#
#     In [ ]: %quickref  # Pops open a quick reference card
#
#     In [ ]: ! 	       # spawning out to the operating system;
#                          e.g files=!ls will fill the variable files
#                          with a list of files in your directory.
#
#
# IPython also contains a number of [“magic” commands](https://ipython.org/ipython-doc/dev/interactive/magics.html).
# Two examples are
#
#     In [ ]: %matplotlib inline  # makes plots within the web browser instead of popping up a new window
#
#     In [ ]: %whos               # lists the vectors, etc. that you have defined.
#
# IPython also has lots of [keyboard shortcuts](https://ipython.org/ipython-doc/1/interactive/notebook.html#keyboard-shortcuts) – the main one is shift-enter to run a cell.

# %% [markdown]
# # Run notebook as slideshow
#
# First, choose `view` then `slideshow` from top memu.
#
# From command line, run this notebook as:
#
#     $ jupyter nbconvert ast502-lecture2.ipynb --to slides --post serve

# %% [markdown]
# # A few useful links before we move on
#
# ## Python:
#
# If you need a python refresher. A good place to start is **Appendix A** (more specifically A3) in the textbook.
#
# For true beginners, I also recommend the [codecademy](https://www.codecademy.com/) course on Python.  It is free and does a good job of walking you through things that you need to learn.
#
# And, of course, you can google 'python tutorial' (or some such) and find a plethora of things that you may or may not like better.
#
# ## NumPy
#
# NumPy is short for Numerical Python. It is the foundational package for scientific computing in Python. It is a library which will allow us to work with **arrays** that are more efficient for storing and manipulating data than other Python data structures (or C++ for that matter).
#
# ## SciPy
#
# [SciPy](http://docs.scipy.org/doc/scipy/reference/) is an "open-source software for mathematics, science, and engineering". It is a suite of tools for data analysis including integration, statistical functions, interpolation.  It is built on top of Numpy. Where Numpy is intended for array *manipulation*, Scipy is intended for *analysis*. This is where many useful tools will be.  It may be worth looking at the users guide to get an idea of the kinds of functions are available.

# %% [markdown]
# ## Scikit-learn
#
# The [Scikit-learn library](http://scikit-learn.org/) forms the core of computing tools that we will use for this class.  The "scikit"s are add-ons to **scipy**.  Scikit-learn is the add-on for machine learning.
#
# It probably needs its own introductory tutorial as both the input and output may not be quite what you would have expected.    You might want to spend some time going through their quick start guide, user's guide and tutorials here: [http://scikit-learn.org/stable/documentation.html](http://scikit-learn.org/stable/documentation.html).
#
# Ironically, Scikit-learn is **NOT** really intended for Big Data (despite the title of the course).  We will be using it to learn the basics of machine learning and big data analysis.  However, we'll see that if you want to do any real Big Data analysis, you'll need other tools.
#
# ## Matplotlib
#
# It is generally useful to be able to visualize your data.  We will do that using the
# [matplotlib](http://matplotlib.org/) library.   Most of you should be familiar with it already, but we will likely be making some plots that are more complex than you are used to.  One nice resource is this [thumbnail gallery](http://matplotlib.org/gallery.html) which you can use to figure out how to make a new plot.

# %%
# let's make sure that we can plot something 
# %matplotlib inline 

# invoke pyplot in matplotlib, give it an alias
import matplotlib.pyplot as plt  
import numpy as np

x = np.linspace(0, 2*np.pi, 300)
y = np.sin(x)
plt.figure(figsize=(12,4))
plt.plot(x, y)
y2 = np.sin(x**2)
plt.plot(x, y, label=r'$\sin(x)$')
plt.plot(x, y2, label=r'$\sin(x^2)$')
plt.title('Some functions')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend();

# %% [markdown]
# # astroML dataset
#
# AstroML provided a few built-in dataset that the various tools introduced can be tested on. If you are using the Ivezic book (and related notebooks) for your seminar, you should download those and make sure that they work.
#
# The datasets include:
#
# (1) SDSS Imaging Data catalog (from a small, 20 sq deg part of the sky). You will use it for various density estimates and classification problems.
#
# (2) A subset of SDSS spectra, fully calibrated, with classification and redshifts. You will use when doing dimension reduction tasks (e.g. PCA)
#
# (3) SDSS galaxy and quasar catalogs
#
# (4) SDSS (SEGUE) stellar parameters
#
# (5) SDSS standard catalog from `stripe 82`
#
# (6) LINEAR Stellar light curves, obviously for time-series analysis.
#
# See Sec 1.5 for a more detailed description. Today, let's just make sure that the first three catalogs are loaded and work. Note that you need to only download it once. Then data will be written under `astroML_data` in your home directory.

# %%
# SDSS Imaging Data. 
from astroML.datasets import fetch_imaging_sample

data = fetch_imaging_sample()
data.shape
# Out:
# (330753,)

# %%
data.dtype.names[:10]
# Out:
# ('ra', 'dec', 'run', 'rExtSFD', 'uRaw', 'gRaw', 'rRaw', 'iRaw', 'zRaw', 'uErr')

# %%
data['dec'][:5]
# Out:
# array([-0.508718, -0.551157, -0.570892, -0.426526, -0.505625])

# %%
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2019)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
import numpy as np
from matplotlib import pyplot as plt
from astroML.datasets import fetch_imaging_sample

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=8, usetex=True)


def get_stars_and_galaxies(Nstars=5000, Ngals=5000):
    """Get the subset of star/galaxy data to plot"""
    data = fetch_imaging_sample()

    objtype = data['type']

    stars = data[objtype == 6][:Nstars]
    galaxies = data[objtype == 3][:Ngals]

    return stars, galaxies


def plot_stars_and_galaxies(stars, galaxies):
    """Plot the star and galaxy data"""
    # Note: we use plot() rather than scatter() because it's more efficient
    # for large numbers of points.
    # Scatter should be used only when points need to be different colors
    # and/or sizes
    plot_kwargs = dict(color='k', linestyle='none', marker=',')

    fig = plt.figure(figsize=(12, 8.75))

    ax1 = fig.add_subplot(221)
    ax1.plot(galaxies['gRaw'] - galaxies['rRaw'],
             galaxies['rRaw'],
             **plot_kwargs)

    ax2 = fig.add_subplot(223, sharex=ax1)
    ax2.plot(galaxies['gRaw'] - galaxies['rRaw'],
             galaxies['rRaw'] - galaxies['iRaw'],
             **plot_kwargs)

    ax3 = fig.add_subplot(222, sharey=ax1)
    ax3.plot(stars['gRaw'] - stars['rRaw'],
             stars['rRaw'],
             **plot_kwargs)

    ax4 = fig.add_subplot(224, sharex=ax3, sharey=ax2)
    ax4.plot(stars['gRaw'] - stars['rRaw'],
             stars['rRaw'] - stars['iRaw'],
             **plot_kwargs)

    # set labels and titles
    ax1.set_ylabel('r')
    ax2.set_ylabel('r - i')
    ax2.set_xlabel('g - r')
    ax4.set_xlabel('g - r')
    ax1.set_title('Galaxies')
    ax3.set_title('Stars')

    # set axis limits
    ax2.set_xlim(-1, 3)
    ax3.set_ylim(22.5, 14)
    ax4.set_xlim(-1, 3)
    ax4.set_ylim(-1, 2)

    # adjust tick spacings on all axes
    for ax in (ax1, ax2, ax3, ax4):
        ax.xaxis.set_major_locator(plt.MultipleLocator(1))
        ax.yaxis.set_major_locator(plt.MultipleLocator(1))

#------------------------------------------------------------
# Generate and show the plot
stars, galaxies = get_stars_and_galaxies()
plot_stars_and_galaxies(stars, galaxies)
plt.show()

# %%
# now some spetroscopic data
# %pylab
# %matplotlib inline 
from astroML.datasets import fetch_sdss_spectrum
plate = 1615 # SDSS spectroscopic plate number
mjd = 53166 # when the observerations were taken
fiber = 508 # fiber id
data = fetch_sdss_spectrum(plate, mjd, fiber)
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib
# ...
# [========================================]  182.8kb / 182.8kb
# caching to /Users/jiachuanxu/astroML_data/SDSSspec/1615/spSpec-53166-1615-508.fit

# %%
fig = plt.figure(figsize=(12, 8.75))
ax = plt.axes()
ax.plot(data.wavelength(), data.spectrum, '-k')
ax.set_xlabel(r'$\lambda (\AA)$')
ax.set_ylabel('Flux')
# Out:
# Text(0, 0.5, 'Flux')

# %%
# Now let's try the SDSS quasar catalog
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2013)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
from matplotlib import pyplot as plt
from astroML.datasets import fetch_dr7_quasar

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=8, usetex=True)

#------------------------------------------------------------
# Fetch the quasar data
data = fetch_dr7_quasar()

# select the first 10000 points
data = data[:10000]

u = data['mag_u']
g = data['mag_g']
r = data['mag_r']
i = data['mag_i']
z = data['redshift']

data.shape
# Out:
# downloading DR7 quasar dataset from http://das.sdss.org/va/qsocat/dr7qso.dat.gz to /Users/jiachuanxu/astroML_data
# ...
# [=========================================]  12.82Mb / 12.82Mb
# (10000,)

# %%
#------------------------------------------------------------
# Plot the quasar data
fig, ax = plt.subplots(figsize=(10, 6.75))
ax.plot(z, u - g, marker='.', markersize=2, linestyle='none', color='black')

ax.set_xlim(0, 3.5)
ax.set_ylim(-0.5, 2.0)

ax.set_xlabel(r'${\rm redshift}$')
ax.set_ylabel(r'${\rm u-g}$')


plt.show()

# %% [markdown]
# # Topics 1: Statistics
#
# Chap 3: Probability and statistical distributions (XF)
#
# Chap 4: Classical Statistical Inference:
#
# - Maximum likelihood estimation
# - confidence estimates
# - hypothesis testing
# - non-parametric modeling
#
# Chap 5: Bayesian Statistical Inference:
#
# - Bayesian priors and model selection
# - Markov Chain Monte Carlo (MCMC)

# %% [markdown]
# # Topic 2: Data Mining (characterizing data)
#
# Chap 6: Searching for structure in point data
#
# - density estimation (non-parametric and parametric)
# - clustering and correlation function
#
# Chap 7: Dimensionality and its reduction
#
# - Principle Component Analysis
# - manifold learning
# - independent component analysis

# %% [markdown]
# # Topics 3: Machining Learning  (interpreting data)
#
# Chap 8: Regression and model fitting
#
# - linear models; non-linear models
#
# Chap 9: Classification
#
# - generative models
# - support vector machine; decision trees
# - deep learning/neural network
#
# Chap 10: Time Series Analysis
#
# - Periodic; localized (bursts); stochastic processes

# %% [markdown]
# # Student lectures
#
# I will email the class list of topics and set up survey, each student should choose three topics of interests to present. I will send assignments by the end of this week.
#
# Survey link: https://www.surveymonkey.com/r/87FLFJQ
#
# Basic lecture format:
# - review basic concepts
# - introduce basic computational tools/codes
# - lead exercise demonstrations - with examples from astroML
# - compare different techniques and codes, in terms of their relative accuray, interpretabilty, simplicity and speed
# - and review other astro applications from recent literature/your research

# %% [markdown]
# # List of topics
#
# we have 17 open slots for 19 students/topics. I will double up two pairs.
#
# 1. maximum likelihood estimate (4.2 - 4.5)
# 2. non-parametric modeling (4.8 - 4.9)
# 3. Bayesian parameter estimation (5.3, 5.6)
# 4. Bayesian model selection (5.4, 5.7)
# 5. MCMC (5.8)
# 6. density estimation  (non-parametric) - KDE, nearest neighbor (6.1, 6.2)
# 7. density estimation (parametric) - GMM, XD (6.3)
# 8. clustering (6.4, 6.5)
# 9. Dimensionality: PCA (7.1 - 7.3)
# 10. Dimensionality: Manifold learning and ICA (7.5, 7.6)
# 11. Regression: linear models (8.1 - 8.5)
# 12. Regression: nonlinear models (8.7 - 8.10)
# 13. Classification: Generative (9,3)
# 14. Classification: SVM (9.5, 9.6)
# 15. Classification: trees and forest (9.7)
# 16. Deep learning and neural networks (9.8)
# 17. time series: basic models (10.1, 10.2)
# 18. time series: periodic (10.3)
# 19. time series: localized and stochastic (10.4, 10.5)

# %% [markdown]
# Student-led seminars start Feb 3. To prepare your lectures, please:
#
# - During the week before the seminar, come to see me, either during office hour (Wednesday AM), or any other time that you can find me, to discuss your class. Preferrably, at that time, you will already have a version of the notebook that we can go through together.
#
# - You should post your notebook the night before class. Everyone should update from github before class.
#
# - Students are encouraged to send feedback to the lecturer. I will send mine as well, and you can come to see me for a debriefing.
#
# - You should update your notebook after the feedback.
#
# And you can find a preliminary lecture schedule on the class website:
#
# http://sancerre.as.arizona.edu/~fan/Home/AST502-information.html
#
# Dos and Don'ts when giving lectures:
#
# https://www.unodc.org/pdf/india/publications/guide_for_Trainers/12_appendix3-checklistofdosdontswhenlecturing.pdf
#
# - Rehearse
# - Focus on a small number of topics (don't get greedy)
# - Slow down
# - Look at your audience and be confident
#
# Please let me know as soon as possible if there is an issue with your assignment.
